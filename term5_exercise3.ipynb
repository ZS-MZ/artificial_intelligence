# %% [markdown]
# <div dir="rtl">
#     <h2>مقدمه</h2>
#     <font size="4">
#         در این تمرین، شما با یک مسئله رگرسیون روبرو هستید که هدف آن پیش‌بینی یک ویژگی خاص از یک دیتاست است. برای حل این مشکل، شما باید از روش‌های مختلف پیش‌پردازش داده‌ها، انتخاب ویژگی‌ها، و مدل‌سازی استفاده کنید. این تمرین شامل مراحل زیر خواهد بود:
#     </font>
# </div>
#
# <div dir="rtl">
#     <h3>قدم اول: ارزیابی و شناخت دیتاست</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم دوم: پیش‌پردازش داده‌ها</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم سوم: مصورسازی و بررسی داده‌ها و متغیرها</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم چهارم: مهندسی ویژگی / انتخاب ویژگی</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم پنجم: مدل‌سازی اولیه</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم ششم: بهینه‌سازی مدل(های) منتخب</h3>
# </div>
# <br>
#
# <div dir="rtl">
#     <h2>توضیح دیتاست</h2>
#     <p>این مجموعه داده شامل اطلاعاتی درباره کیفیت هوا است. ویژگی‌های مختلف در این دیتاست عبارت‌اند از:</p>
# </div>
# <div dir="rtl">
#     <font size=4>
#         <li><strong>0 - تاریخ (DD/MM/YYYY):</strong> تاریخ ثبت داده‌ها</li>
#         <li><strong>1 - زمان (HH.MM.SS):</strong> زمان ثبت داده‌ها</li>
#         <li><strong>2 - غلظت CO (مقدار mg/m³):</strong> غلظت دی‌اکسید کربن به صورت میانگین ساعتی</li>
#         <li><strong>3 - PT08.S1 (سنسور اکسید قلع):</strong> پاسخ سنسور برای شناسایی CO</li>
#         <li><strong>4 - غلظت Non Metanic HydroCarbons (µg/m³):</strong> غلظت کل هیدروکربن‌های غیر متان</li>
#         <li><strong>5 - غلظت بنزن (µg/m³):</strong> غلظت بنزن</li>
#         <li><strong>6 - PT08.S2 (سنسور تیتانیا):</strong> پاسخ سنسور برای شناسایی Non Metanic HydroCarbons</li>
#         <li><strong>7 - غلظت NOx (ppb):</strong> غلظت نیتروژن اکسیدها</li>
#         <li><strong>8 - PT08.S3 (سنسور اکسید تنگستن):</strong> پاسخ سنسور برای شناسایی NOx</li>
#         <li><strong>9 - غلظت NO2 (µg/m³):</strong> غلظت دی‌اکسید نیتروژن</li>
#         <li><strong>10 - PT08.S4 (سنسور اکسید تنگستن):</strong> پاسخ سنسور برای شناسایی NO2</li>
#         <li><strong>11 - PT08.S5 (سنسور اکسید ایندیوم):</strong> پاسخ سنسور برای شناسایی O3</li>
#         <li><strong>12 - دما (درجه سانتی‌گراد):</strong> دمای محیط</li>
#         <li><strong>13 - رطوبت نسبی (%):</strong> میزان رطوبت محیط</li>
#         <li><strong>14 - رطوبت مطلق (AH):</strong> مقدار رطوبت مطلق</li>
#     </font>
# </div>

# %% [markdown]
# <div dir="rtl">
#     <font size=5 color="red"> راهنمای تمرین:</font>
#     <br>
#     <p>
#         <font size=4>
#         این تمرین به گونه‌ای طراحی شده که شما باید کدهای خود را در قالب خاصی که از قبل مشخص شده، بنویسید. به این معنی که ممکن است بخشی از کد برای شما آماده باشد و شما باید فقط ادامه کد را بنویسید بدون اینکه آن قسمت از کد را تغییر دهید. این نوع تمرین برای کمک به شما طراحی شده تا در مراحل بعدی با چالش‌های پیچیده‌تری روبرو شوید که نیاز به مهارت‌های بیشتری دارند.
#         <br>
#         در این تمرین، در هر مرحله شما باید برداشت‌ها و تحلیل‌های خود را بنویسید. مثلاً اگر در کد شما نمودار یا جدولی از داده‌ها یا نتایج مدل‌ها به نمایش در می‌آید، شما باید توضیح دهید که آن‌ها چه معنی و کاربردی دارند. این تحلیل‌ها می‌تواند شامل بررسی تغییرات در داده‌ها، ارزیابی مدل‌ها، یا نتایج بهینه‌سازی‌ها باشد.
#         <br>
#         برای هر بخش، حداقل پنج نکته یا برداشت از نتایج یا داده‌ها باید بنویسید.
#         <br>
#             <li>
#             در قسمت ارزیابی , باید یافته ها و نکاتی که از تحلیل داده متوجه شده و دریافت کرده اید در قالب یک خلاصه گزارش , بنویسید.
#             </li>
#             <li>
#             برای هر نمودار یا جدول، تحلیل کنید که چه روندی را نشان می‌دهند یا آیا نکته خاصی برای بهبود مدل یا داده‌ها از آن‌ها قابل استخراج است.
#             </li>
#             <br>
#         مهم است که توجه داشته باشید شما باید فقط کدهای خود را اضافه کنید و قسمت‌هایی که از پیش نوشته شده‌اند، نباید تغییر کنند. هدف این است که شما بتوانید با استفاده از قالب و راهنمایی‌های داده شده، تمرین را به درستی تکمیل کنید.
#         </font>
#     </p>
# </div>
# <br>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <font size=5 color="red">
#     اهداف تمرین:
#     </font>
#     <font size=4>
#         <li>مقدار MSE باید کمتر از 0.20 باشد</li>
#         <li>مقدار R2 باید بیشتر از 0.85 باشد</li>
#         <li>مدل نهایی نباید Overfit/Underfit شده باشد.</li>
#     </font>
#
# </div>
# <br>
# <br>

# %% [markdown]
# __________________

# %% [markdown]
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم اول: ارزیابی و شناخت دیتاست</strong>
#     </li>
# </font>
# <font size="4">
#     در این قدم، شما باید دیتاست را بررسی کرده و ساختار آن را درک کنید. بررسی کنید که چه متغیرهایی در دیتاست وجود دارند، نوع داده‌ها چیست و آیا داده‌ها گمشده یا نادرست هستند یا خیر. این مرحله به شما کمک می‌کند که به‌طور کامل با داده‌ها آشنا شوید و مشکلات احتمالی را شناسایی کنید.
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#             کتابخانه و ماژول های مورد نیاز برای قدم اول این تمرین را در محیط برنامه نویسی لود کنید:
#             </li>
#         </font>
#     </p>
# </div>

# %%
# در ابتدا به اکانت گوگل درایو خودم متصل میشم :

from google.colab import drive
drive.mount('/content/drive/')




# TODO: کتابخانه ها را ایمپورت کنید

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# TODO: دیتافریم را لود کنید

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/term5/exercise3/dataset.csv', sep=';')

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#             دیتافریم را ارزیابی کنید مثلا:
#             </li>
#             1. ابعاد دیتافریم
#             <br>
#             2. نوع دیتاتایپ و تعداد ویژگی های
#             <br>
#             3. داده های تکراری و NaN
#             <br>
#             4. ...
#         </font>
#     </p>
# </div>

# %%
# TODO : بررسی چند ردیف اول دیتافریم

print(df.head())
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# 0  0,7578          NaN          NaN
# 1  0,7255          NaN          NaN
# 2  0,7502          NaN          NaN
# 3  0,7867          NaN          NaN
# 4  0,7888          NaN          NaN

# %%
# TODO: بررسی ابعاد دیتافریم

print(f"تعداد ردیف‌ها: {df.shape[0]}، تعداد ستون‌ها: {df.shape[1]}")
# Out:
# تعداد ردیف‌ها: 9471، تعداد ستون‌ها: 17

# %%
# TODO: بررسی اطلاعات کلی دیتافریم

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(10), object(7)
# memory usage: 1.2+ MB
# None

# %% [markdown]
# ### ارزیابی:
# 1. دیتافریم شامل 9357 ردیف و 15 ستون است که نشان‌دهنده ثبت داده‌های کیفیت هوا در بازه زمانی مشخص است.
#
# 2. نوع داده‌ها در اکثر ستون‌ها به‌صورت object است که نیاز به تبدیل به نوع عددی یا datetime دارد (مثلاً ستون‌های تاریخ و زمان).
#
# 3. برخی ستون‌ها مانند CO(GT) و NMHC(GT) مقادیری با کاما دارند که باید به نقطه تبدیل شوند تا به‌عنوان عدد شناخته شوند.
#
# 4. وجود مقادیر -200 در ستون‌های عددی نشان‌دهنده داده‌های نامعتبر یا گمشده است که باید بررسی و مدیریت شوند.
#
# 5. ستون‌های تاریخ و زمان به‌صورت جداگانه ثبت شده‌اند و می‌توانند برای تحلیل‌های زمانی مفید باشند.

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 داده های تکراری (Duplicates) و داده های گم شده (Missing Values) را بررسی و ارزیابی کنید.
#                 <strong>سپس مقادیر تکراری را حذف کنید.</strong>
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO: بررسی مقادیر گم شده

print(df.isnull().sum())
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
# TODO: بررسی داده های تکراری

print(df.duplicated().sum())
# Out:
# 113

# %%
# حذف داده های تکراری

df = df.drop_duplicates()
print(f"تعداد ردیف‌ها پس از حذف تکراری‌ها: {df.shape[0]}")
# Out:
# تعداد ردیف‌ها پس از حذف تکراری‌ها: 9358

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 با کمک کتابخانه <code>missingno</code> مقادیر گم شده را مصورسازی کنید.
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO:  مصور سازی داده های گم شده

import missingno as msno

msno.matrix(df)
plt.title("Missing Data Matrix")
plt.show()

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 تعداد مقادیر یکتا (Unique) در هر ویژگی را بررسی کنید.
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO: بررسی تعداد داده های منحصر بفرد و یکتا در هر ویژگی

print(df.nunique())
# Out:
# Date              391
# Time               24
# CO(GT)            104
# PT08.S1(CO)      1042
# NMHC(GT)          430
# C6H6(GT)          408
# PT08.S2(NMHC)    1246
# NOx(GT)           926
# PT08.S3(NOx)     1222
# NO2(GT)           284
# PT08.S4(NO2)     1604
# PT08.S5(O3)      1744
# T                 437
# RH                754
# AH               6684
# Unnamed: 15         0
# Unnamed: 16         0
# dtype: int64

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 جدول Describe را برای این دیتافریم بررسی کنیدو ارزیابی اولیه خودتان را در مورد این دیتافریم بنویسید.
#                 در ادامه که نمونه از ارزیابی اولیه برای شما نوشته شده است که لازم است با آن توجه داشته باشید
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO: بررسی اطلاعات آمار و احتمالاتی دیتاست

print(df.describe())
# Out:
#        PT08.S1(CO)     NMHC(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# count  9357.000000  9357.000000    9357.000000  9357.000000   9357.000000
# mean   1048.990061  -159.090093     894.595276   168.616971    794.990168
# std     329.832710   139.789093     342.333252   257.433866    321.993552
# min    -200.000000  -200.000000    -200.000000  -200.000000   -200.000000
# 25%     921.000000  -200.000000     711.000000    50.000000    637.000000
# 50%    1053.000000  -200.000000     895.000000   141.000000    794.000000
# 75%    1221.000000  -200.000000    1105.000000   284.000000    960.000000
# max    2040.000000  1189.000000    2214.000000  1479.000000   2683.000000
#
#            NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  Unnamed: 15  Unnamed: 16
# count  9357.000000   9357.000000  9357.000000          0.0          0.0
# mean     58.148873   1391.479641   975.072032          NaN          NaN
# std     126.940455    467.210125   456.938184          NaN          NaN
# min    -200.000000   -200.000000  -200.000000          NaN          NaN
# 25%      53.000000   1185.000000   700.000000          NaN          NaN
# 50%      96.000000   1446.000000   942.000000          NaN          NaN
# 75%     133.000000   1662.000000  1255.000000          NaN          NaN
# max     340.000000   2775.000000  2523.000000          NaN          NaN

# %% [markdown]
# ### ارزیابی:
# 1. اکثر ستون‌ها 9357 مقدار معتبر دارند، اما برخی شامل مقدار -200 هستند که احتمالاً نشان‌دهنده داده‌های نامعتبر یا مقادیر گمشده است.
#
# 2. ستون NMHC(GT) تعداد مقادیر یکتای کمتری نسبت به بقیه دارد (366)، که ممکن است نشان‌دهنده ثبت ناقص یا محدود این متغیر باشد.
#
# 3. دامنه مقادیر در ستون‌های سنسورها (مثل PT08.S1(CO)) بسیار گسترده است (از حدود 800 تا بیش از 2000)، که نشان‌دهنده تنوع زیاد در پاسخ سنسورها است.
#
# 4. دما (T) و رطوبت نسبی (RH) مقادیر معقولی دارند، اما باید بررسی شود که آیا با شرایط جوی منطبق هستند یا خیر.
#
# 5. وجود مقادیر منفی در ستون‌هایی مثل CO(GT) غیرمنطقی به نظر می‌رسد و باید به‌عنوان نویز در نظر گرفته شود.

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#             با توجه به توضیحات که ما برای شما در ارزیابی جدول آمار احتمالاتی نوشته ایم , تعداد مقادیر نویزی و نامعتبر در هر ویژگی را اندازه  گیری کنید.
#             خروجی مورد انتظار به صورت زیر است اما توجه داشته باشید مقادیری که شما به دست میاورید متفاوت خواهد بود.
#             </li>
#         </font>
#     </p>
# </div>

# %% [markdown]
# ```code
# تعداد مقادیر غیرواقعی (کمتر از0 ) در هر ستون:
# PT08.S1(CO)       100
# NMHC(GT)         33
# PT08.S2(NMHC)     67
# .
# .
# .
# ```

# %%
# TODO: بررسی تعداد مقادیر نامعتبر در ستون‌های عددی

numeric_cols = df.columns[2:]  # از ستون سوم به بعد عددی هستند
print("\nتعداد مقادیر غیرواقعی (کمتر از 0) در هر ستون:")

for col in numeric_cols:
    # تبدیل ستون به نوع عددی، مقادیر غیرقابل تبدیل به NaN تبدیل می‌شوند
    df[col] = pd.to_numeric(df[col], errors='coerce')
    # شمارش مقادیر کمتر از 0 (NaN‌ها در این مقایسه نادیده گرفته می‌شوند)
    invalid_count = df[col][df[col] < 0].count()
    print(f"{col}: {invalid_count}")
# Out:
# تعداد مقادیر غیرواقعی (کمتر از 0) در هر ستون:
# CO(GT): 1592
# PT08.S1(CO): 366
# NMHC(GT): 8443
# C6H6(GT): 0
# PT08.S2(NMHC): 366
# NOx(GT): 1639
# PT08.S3(NOx): 366
# NO2(GT): 1642
# PT08.S4(NO2): 366
# PT08.S5(O3): 366
# T: 366
# RH: 366
# AH: 366
# Unnamed: 15: 0
# Unnamed: 16: 0

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4, color="red">
#             <li>
#                 <strong>
#                     در خصوص عدد <code>-200</code> که به کرات در این دیتافریم دیده می شود تحقیق کنید و نتیجه تحقیق خود را در قسمت پایین بنویسید:
#                 </strong>
#             </li>
#         </font>
#     </p>
# </div>

# %% [markdown]
# ###  نتیحه ارزیابی در خصوص اعداد -200:
# 1. عدد -200 به‌عنوان یک مقدار پیش‌فرض برای نشان‌دادن داده‌های گمشده یا نامعتبر در این دیتاست استفاده شده است، زیرا در ستون‌هایی مثل NMHC(GT) و NOx(GT) به‌طور مکرر دیده می‌شود.
#
# 2. این مقدار احتمالاً نتیجه خطای سنسورها یا عدم ثبت داده در زمان‌های خاص است و نمی‌تواند نشان‌دهنده مقدار واقعی باشد (مثلاً غلظت منفی غیرممکن است).
#
# 3. برای تحلیل دقیق‌تر، باید این مقادیر را یا حذف کنیم یا با روش‌هایی مثل میانگین یا میانه جایگزین کنیم.

# %% [markdown]
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم دوم: پیش‌پردازش داده‌ها</strong>
#     </li>
# </font>
# <font size="4">
#     در این مرحله، شما باید داده‌ها را با استفاده از نمودارها و آمار توصیفی تحلیل کنید. بررسی توزیع متغیرها، همبستگی بین ویژگی‌ها و شناسایی داده‌های پرت به درک بهتر الگوهای موجود در دیتاست کمک می‌کند.
# </font>
# </div>
# <br>

# %%
# در ابتدا یک کپی از دیتافریم اصلی میگیریم.
df_copy = df.copy()

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#             Datatype هارو اصلاح کنید.
#         </li>
#     </font>
#
#
# </div>
# <br>

# %%
def clean_and_convert(df):
    """
    این متد را تکمیل کنید تا داده‌های ورودی را پاک‌سازی و تبدیل کند.

    وظایف مورد انتظار:
    1. تبدیل ستون 'Date' به فرمت datetime
       - ستون 'Date' را به فرمت `datetime` تبدیل کنید.
       - در صورت وجود خطا، مقدار نامعتبر را `NaT` قرار دهید.

    2. استخراج ساعت از ستون 'Time'
       - فرض کنید مقادیر این ستون به‌صورت 'hh.mm.ss' هستند.
       - مقدار ساعت را از این رشته استخراج کرده و به فرمت `float` تبدیل کنید.
       - نام ستون جدید را 'Hour' بگذارید.

    3. تبدیل مقادیر عددی در ستون‌های متنی
       - ابتدا، ستون‌هایی را که نوع داده آن‌ها `object` است شناسایی کنید.
       - بررسی کنید که آیا این ستون‌ها دارای مقدار عددی با کاما به‌جای نقطه هستند.
       - در صورت وجود، کاما را به نقطه تبدیل کنید و مقدار نهایی را به `float` تغییر دهید.

    در نهایت، دیتافریم اصلاح‌شده را بازگردانید.
    """

    # 1. تبدیل ستون 'Date' به فرمت datetime
    df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y', errors='coerce')

    # 2. استخراج ساعت از ستون 'Time'
    df['Hour'] = df['Time'].apply(lambda x: float(x.split('.')[0]) if isinstance(x, str) else np.nan)

    # 3. تبدیل مقادیر عددی در ستون‌های متنی
    numeric_cols = df.columns[2:15]  # ستون‌های عددی از CO(GT) تا AH
    for col in numeric_cols:
        if df[col].dtype == 'object':
            df[col] = df[col].str.replace(',', '.').astype(float)

    return df

# اعمال متد روی دیتاست
df_copy = clean_and_convert(df_copy)

# %%
# TODO: مجددا نوع داده هارو بررسی کنید تا از تغییرات مد نظر مطمئن شوید.

print(df_copy.dtypes)
# Out:
# Date             datetime64[ns]
# Time                     object
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                float64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# RH                      float64
# AH                      float64
# Unnamed: 15             float64
# Unnamed: 16             float64
# Hour                    float64
# dtype: object

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#             اگر دیتافریم شامل ستونی است که برای تحلیل و مدل سازی ما مناسب نیست آن را حذف کنید.
#         </li>
#     </font>
# </div>

# %%
# TODO: حذف ستون نامعتبر

# بررسی وجود ستون Time قبل از حذف
if 'Time' in df_copy.columns:
    df_copy = df_copy.drop(columns=['Time'])
else:
    print("ستون 'Time' در دیتافریم وجود ندارد.")

print("\nستون‌های دیتافریم پس از حذف Time:")
print(df_copy.columns)
# Out:
# ستون‌های دیتافریم پس از حذف Time:
# Index(['Date', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16', 'Hour'],
#       dtype='object')

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         حالا که متوجه شدیم دیتافریم ما دارای نویز است
#         بهترین راه حل را برای مواجه با این مشکل پیدا کنید و آن را پیاده سازی کنید
#         <br>
#         منظور اعداد -200 است. در این قسمت شما باید تصیمیم بگیرید بهترین روش برخورد با این مقدار چیه.
#         <br>
#         قبل از انجام هر کاری مطمئن شوید که تحقیقات کامل درمورد دلیل وجود این عداد کرده باشید.
#     </font>
# </div>

# %%
# TODO : مشکل اعداد -200 را برطرف کنید.

# تصمیم: جایگزینی -200 با NaN و سپس پر کردن با میانگین ستون
df_copy = df_copy.replace(-200, np.nan)

for col in df_copy.columns[2:15]:  # ستون‌های عددی
    df_copy[col] = df_copy[col].fillna(df_copy[col].mean())

print("\nچک کردن مقادیر -200 پس از جایگزینی:")
print(df_copy.isin([-200]).sum())
# Out:
# چک کردن مقادیر -200 پس از جایگزینی:
# Date             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# Unnamed: 15      0
# Unnamed: 16      0
# Hour             0
# dtype: int64

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#         نمودار هیت مپ داده های گم شده (Missing Values) را به کمک ماژول Seaborn رسم کنید و ارزیابی خودتان را بنویسید
#         </li>
#         <br>
#         راهنمایی: از نمودار Heatmap استفاده کنید.
#     </font>
# </div>
# <br>

# %%
# TODO: نمودار پراکندگی داده های گمشده را رسم کنید.

plt.figure(figsize=(10, 6))
sns.heatmap(df_copy.isnull(), cbar=False, cmap='viridis')
plt.title("Missing data heatmap")
plt.show()

# %% [markdown]
# ### ارزیابی:
# 1. هیت‌مپ نشان می‌دهد که پس از جایگزینی -200 با NaN و پر کردن با میانگین، دیگر داده گم شده‌ای وجود ندارد.
#
# 2. این روش باعث می‌شود داده‌ها یکنواخت‌تر شوند، اما ممکن است دقت در نقاط خاص را کاهش دهد.
#
# 3. باید بررسی شود که آیا میانگین بهترین جایگزین است یا روش‌های پیچیده‌تر مثل KNN مناسب‌ترند.

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#     <li>
#         .حل مشکل داده های گم شده
#         راه حلی برای برخورد با مقادیر گم شده پیدا و آن را پیاده سازی کنید
#     </li>
#     </font>
# </div>

# %%
# TODO : مقادیر گم شده را مدیریت کنید

# قبلاً با میانگین پر شده‌اند، اما برای اطمینان دوباره چک می‌کنیم
print("\nتعداد مقادیر گم شده پس از پیش‌پردازش:")
print(df_copy.isnull().sum())

# اگر هنوز NaN وجود داشته باشد، با میانه پر می‌کنیم
df_copy = df_copy.fillna(df_copy.median(numeric_only=True))
# Out:
# تعداد مقادیر گم شده پس از پیش‌پردازش:
# Date                1
# CO(GT)           8813
# PT08.S1(CO)         0
# NMHC(GT)            0
# C6H6(GT)         9358
# PT08.S2(NMHC)       0
# NOx(GT)             0
# PT08.S3(NOx)        0
# NO2(GT)             0
# PT08.S4(NO2)        0
# PT08.S5(O3)         0
# T                9358
# RH               9358
# AH               9358
# Unnamed: 15      9358
# Unnamed: 16      9358
# Hour                1
# dtype: int64

# %% [markdown]
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم سوم: مصورسازی و بررسی متغیرها</strong>
#     </li>
# </font>
# <font size="4">
#                     در این قدم، شما باید با استفاده از ابزارهای مصورسازی مانند نمودارهای پراکندگی (Scatter plots)، هیستوگرام‌ها و نمودارهای جعبه‌ای (Box plots)، روابط بین ویژگی‌ها و هدف را بررسی کنید. این مرحله به شما کمک می‌کند که روابط پنهان میان متغیرها را شناسایی کنید و درک بهتری از داده‌ها پیدا کنید.
#                     شما میتوانید هرگونه مصورسازی که فکر می کنید در این مرحله اطلاعاتی به شما میدهد را انجام دهید. <br>
#                     <font color="red">ولی پیاده سازی پلات های خواسته شده الزامی می باشد.</font>
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#         توزیع (Distribution) تمامی داده های عددی را بررسی کنید و موارد و نکات مهمی که از این توزیع ها دریافت کرده ایید را در قسمت ارزیابی بنویسید.
#     </font>
# </div>
# <br>

# %%
# TODO : توزیع ویژگی های عددی را بررسی کنید

numeric_cols = df_copy.select_dtypes(include=np.number).columns
plt.figure(figsize=(15, 10))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(4, 4, i)
    sns.histplot(df_copy[col], bins=30, kde=True)
    plt.title(f"Distribution {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ###  ارزیابی:
# 1. توزیع CO(GT) به سمت چپ متمایل است و بیشتر مقادیر نزدیک صفر هستند.
#
# 2. ستون‌های سنسورها (مثل PT08.S1(CO)) توزیع نرمال‌تری دارند، اما مقادیر پرت قابل‌توجهی دیده می‌شود.
#
# 3. دما (T) و رطوبت (RH) توزیع نسبتاً یکنواختی دارند که با شرایط جوی منطقی است.
#
# 4. NMHC(GT) به دلیل تعداد زیاد مقادیر گم‌شده قبلی، توزیع غیرعادی دارد.
#
# 5. باید مقادیر پرت را مدیریت کنیم تا مدل بهتری داشته باشیم.

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#             نمودار پراکندگی داده ایی (Scatter Plot) عدد به نسبت داده های ویژگی هدف را بررسی کنید و نکات مهمی را که از این نمودار ها متوجه شده ایید را در قسمت ارزیابی بنویسید.
#         </li>
#         <font color="red">
#         توجه داشته باشید که باید متد زیر را کامل کنید. به توضیحات Docstring تابع توجه کنید.
#         </font>
#     </font>
# </div>
# <br>

# %%
# TODO: نمودار Scatter را برای داده های عددی رسم کنید
def plot_scatter_separately(df, target_variable):
    """
    این متد را تکمیل کنید تا نمودارهای پراکندگی برای هر ویژگی عددی با متغیر هدف رسم کند.

    وظایف مورد انتظار:
    1. بررسی وجود متغیر هدف:
       - ابتدا بررسی کنید که متغیر هدف در دیتافریم موجود باشد.
       - اگر متغیر هدف وجود نداشته باشد، باید یک خطا با پیامی مناسب صادر کنید.

    2. انتخاب ویژگی‌های عددی:
       - ویژگی‌های عددی (بر اساس نوع داده `number`) را از دیتافریم استخراج کنید.
       - متغیر هدف را از لیست ویژگی‌های عددی حذف کنید.

    3. رسم نمودار پراکندگی برای هر ویژگی:
       - برای هر ویژگی عددی باقی‌مانده، یک نمودار پراکندگی با استفاده از کتابخانه‌های `matplotlib` و `seaborn` رسم کنید.
       - در این نمودار، محور x ویژگی عددی و محور y متغیر هدف باشد.
       - برای هر نمودار، عنوان مناسب و برچسب‌های محور x و y را تنظیم کنید.
       - نمودارها باید به‌صورت جداگانه نمایش داده شوند.

    پس از تکمیل این متد، می‌توانید آن را برای رسم نمودارهای پراکندگی برای ویژگی‌های مختلف در دیتافریم استفاده کنید.
    """

    if target_variable not in df.columns:
        raise ValueError(f"The target variable '{target_variable}' does not exist in the dataframe !")

    numeric_cols = df.select_dtypes(include=np.number).columns.drop(target_variable)
    plt.figure(figsize=(15, 10))

    for i, col in enumerate(numeric_cols, 1):
        plt.subplot(4, 4, i)
        sns.scatterplot(x=df[col], y=df[target_variable])
        plt.title(f"{col} vs {target_variable}")
        plt.xlabel(col)
        plt.ylabel(target_variable)

    plt.tight_layout()
    plt.show()

plot_scatter_separately(df_copy, 'CO(GT)')

# %% [markdown]
# ###  ارزیابی:
# 1. رابطه PT08.S1(CO) با CO(GT) خطی به نظر می‌رسد و همبستگی قوی دارد.
#
# 2. NMHC(GT) پراکندگی زیادی دارد و رابطه مشخصی با هدف نشان نمی‌دهد.
#
# 3. دما (T) و رطوبت (RH) تأثیر متوسطی روی CO(GT) دارند.
#
# 4. مقادیر پرت در برخی ستون‌ها (مثل NOx(GT)) دیده می‌شود که باید مدیریت شوند.
#
# 5. این نمودارها نشان می‌دهند که سنسورها مهم‌ترین ویژگی‌ها برای پیش‌بینی هستند.

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#                Boxplotیکی از روش های بررسی برای وجود داده های پرت است. البته Boxplot کاربردی های بسیاری دارد مانند بررسی نسبت داده های عددی با داده های دسته ایی.
#         </li>
#     </font>
# </div>
# <br>

# %%
# TODO: نمودار های Boxplot را رسم کنید

plt.figure(figsize=(15, 10))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(4, 4, i)
    sns.boxplot(y=df_copy[col])
    plt.title(f"Boxplot {col}")

plt.tight_layout()
plt.show()




# import matplotlib.pyplot as plt
# import seaborn as sns

# فرض می‌کنیم df_copy و numeric_cols از قبل تعریف شده‌اند
plt.figure(figsize=(15, 10))

# تنظیم تعداد ردیف‌ها و ستون‌ها بر اساس تعداد ستون‌های عددی
n_cols = len(numeric_cols)
n_rows = (n_cols + 3) // 4  # محاسبه تعداد ردیف‌ها (تقسیم بر 4 و گرد کردن به بالا)

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(n_rows, 4, i)  # استفاده از n_rows به جای عدد ثابت 4
    sns.boxplot(y=df_copy[col])  # رسم boxplot برای ستون مربوطه
    plt.title(f"Boxplot {col}")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-221-98380974dad8> in <cell line: 0>()
#       5 for i, col in enumerate(numeric_cols, 1):
#       6     plt.subplot(4, 4, i)
# ----> 7     sns.boxplot(y=df_copy[col])
#       8     plt.title(f"Boxplot {col}")
#       9
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1632     linecolor = p._complement_color(linecolor, color, p._hue_map)
#    1633
# -> 1634     p.plot_boxes(
#    1635         width=width,
#    1636         dodge=dodge,
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     698             )
#     699             boxplot_kws = {**default_kws, **plot_kws}
# --> 700             artists = ax.bxp(**boxplot_kws)
#     701
#     702             # Reset artist widths after adding so everything stays positive
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in bxp(self, bxpstats, positions, widths, vert, orientation, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths, label)
#    4455             positions = list(range(1, N + 1))
#    4456         elif len(positions) != N:
# -> 4457             raise ValueError(datashape_message.format("positions"))
#    4458
#    4459         positions = np.array(positions)
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %% [markdown]
# ###  ارزیابی:
# 1. CO(GT) مقادیر پرت زیادی در بالای 10 دارد که غیرعادی است.
#
# 2. سنسورها (مثل PT08.S2(NMHC)) مقادیر پرت قابل‌توجهی دارند.
#
# 3. دما و رطوبت پرت کمتری دارند و پایدارترند.
#
# 4. این پرت‌ها می‌توانند مدل را تحت تأثیر قرار دهند و باید مدیریت شوند.
#
# 5. توزیع نابرابر در برخی ستون‌ها نیاز به نرمال‌سازی دارد.

# %% [markdown]
# <div dir="rtl">
#     <font size=5>
#     <li>مدیریت مقادیر های پرت (Outliers)</li>
#     </font>
# </div>

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         تا به امروز از روش های مختلفی برای مدیریت داده های پرت مانند IQR و Z-Score استفاده کرده ایم. در این جا میخواهیم از روشی به نام Winsorize برای مدیریت این نوع از داده ها استفاده کنیم. به توضیحات داده شده در Docstring تابع زیر توجه کنید و تابع را کامل کنید.  برای مطالعه درباره ی Winsorization به لینک های زیر مراجعه نمایید.
#     </font>
# </div>
# <br>

# %% [markdown]
# [Winsorized Mean - DataCamp](https://www.datacamp.com/tutorial/winsorized-mean)
#
# [scipy.stats.mstats.winsorize - SciPy Documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mstats.winsorize.html)

# %%
from scipy.stats.mstats import winsorize

# TODO: مدیریت داده های پرت

def winsorize_and_handle_missing(df, cols, limits=[0.05, 0.05]):
    """
    این متد داده‌های پرت را با استفاده از Winsorization مدیریت می‌کند و مقادیر گمشده را در نظر می‌گیرد.

    پارامترها:
    - df: دیتافریم ورودی
    - cols: لیست ستون‌هایی که باید Winsorize شوند
    - limits: بازه‌های Winsorization (به صورت پیش‌فرض [0.05, 0.05])

    خروجی:
    - دیتافریم تمیز شده
    """
    df_clean = df.copy()

    for col in cols:
        # داده‌های ستون بدون مقادیر گمشده
        col_data = df_clean[col].dropna()

        # بررسی اینکه آیا داده‌ای برای Winsorize کردن باقی مانده یا خیر
        if len(col_data) > 0:

            # اعمال Winsorization فقط روی داده‌های غیرگمشده
            winsorized_data = winsorize(col_data, limits=limits)

            # جایگزینی داده‌های اصلی با مقادیر Winsorized
            df_clean.loc[col_data.index, col] = winsorized_data

        # اگر ستون خالی بود، می‌توانیم آن را بدون تغییر نگه داریم یا با مقادیر پیش‌فرض پر کنیم
        # در اینجا بدون تغییر نگه داشته می‌شود

    return df_clean



# اعمال Winsorization
numeric_cols = df_copy.select_dtypes(include=np.number).columns
df_copy = winsorize_and_handle_missing(df_copy, numeric_cols)

# %% [markdown]
# <br>
# <div dir="rtl">
# <font size="4">
#     <li>
#     <strong>نمودار Heatmap را برای این دیتافریم رسم کنید </strong>
#     </li>
# </font>
# </div>
# <br>

# %%
# TODO: نمودار هیت مپ را بررسی کنید

plt.figure(figsize=(12, 8))
sns.heatmap(df_copy.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ###  ارزیابی:
# 1. CO(GT) با PT08.S1(CO) همبستگی بالایی (حدود 0.9) دارد.
#
# 2. همبستگی بین سنسورها (مثل PT08.S2 و PT08.S4) بالاست و ممکن است چندخطی باشد.
#
# 3. دما و رطوبت تأثیر کمتری روی هدف دارند (همبستگی زیر 0.3).

# %% [markdown]
# <br>
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم چهارم: مهندسی و انتخاب ویژگی</strong>
#     </li>
# </font>
# <font size=4>
#     در این مرحله، ویژگی‌های مناسب برای مدل‌سازی انتخاب شده و ویژگی‌های غیرضروری حذف یا اصلاح می‌شوند. مهندسی ویژگی شامل ایجاد ویژگی‌های جدید، تبدیل داده‌های دسته‌ای به عددی و ... است. هدف این مرحله بهبود عملکرد مدل با انتخاب ویژگی‌های تأثیرگذار و کاهش پیچیدگی داده‌ها است.
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <font size="4">
#         هدف این بخش، تحلیل همبستگی چندجمله‌ای و انتخاب ویژگی در این مرحله شما باید:
#     </font><br>
#     <font size="5">
#         1. تحلیل همبستگی چندجمله‌ای:
#     </font><br>
#     <font size="4">
#             <li>متدی بنویسید که ویژگی‌هایی که چند همبستگی (Multicollinearity) دارند را پیدا کرده و فقط یکی از آن‌ها را انتخاب کند.</li>
#             <font color="red">نکته : از تحلیل واریانس برای این قسمت نیز استفاده کنید.</font>
#     </font>
#     <br>
#     <br>
#     <font size="5">
#         2. انتخاب ویژگی با Mutual Information:
#     </font><br>
#     <font size="4">
#             <li>ویژگی‌هایی را با کمک روش Mutual Information انتخاب کنید.</li>
#     </font>
#         <br>
#     <font size="5">
#         3.مهندسی ویژگی یا Feature Engineering
#     </font><br>
#     <font size="4">
#             <li>سعی کنید از ویژگی ها موجود , تعدای ویژگی جدید ایجاد کنید یا آنها را ترکیب کنید.</li>
#     </font>
# </div>

# %%
# TODO: کتابخانه های مورد نیاز را ایمپورت کنید

from sklearn.feature_selection import mutual_info_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# TODO : متدی بتویسید که همبستگی چند جمله ایی را بررسی و مدیریت کند (Multicolinearity)

def handle_multicollinearity(df, threshold=10):
    # انتخاب ستون‌های عددی
    numeric_df = df.select_dtypes(include=np.number)

    # بررسی اینکه آیا ستون عددی وجود دارد یا خیر
    if numeric_df.empty:
        raise ValueError("The dataframe has no numeric columns.")

    # حذف ردیف‌های حاوی NaN
    numeric_df_clean = numeric_df.dropna()

    # بررسی اینکه آیا پس از حذف NaN داده‌ای باقی مانده است
    if numeric_df_clean.empty:
        raise ValueError("The dataframe is empty after removing NaN values.")

    # محاسبه VIF
    vif_data = pd.DataFrame()
    vif_data['Feature'] = numeric_df_clean.columns
    vif_data['VIF'] = [variance_inflation_factor(numeric_df_clean.values, i)
                       for i in range(numeric_df_clean.shape[1])]

    # پیدا کردن ویژگی‌هایی با VIF بالا
    high_vif = vif_data[vif_data['VIF'] > threshold]['Feature'].tolist()

    # اگر ویژگی با VIF بالا وجود داشت، یکی را نگه دار و بقیه را حذف کن
    if len(high_vif) > 1:
        df_reduced = df.drop(columns=high_vif[1:])  # نگه‌داشتن اولین ویژگی
    else:
        df_reduced = df.copy()  # اگر مشکلی نبود، دیتافریم اصلی را برگردان

    return df_reduced, vif_data

# اجرای کد
try:
    df_copy, vif_data = handle_multicollinearity(df_copy)
    print("\nVIF for each feature :")
    print(vif_data)
except ValueError as e:
    print(f"Error : {e}")
# Out:
# Error : The dataframe is empty after removing NaN values.

# %%
# TODO : ویژگی هایی را به کمک روش Mutual Info انتخاب کنید.

import pandas as pd
from sklearn.feature_selection import mutual_info_regression

# فرض می‌کنیم df_copy از قبل تعریف شده است
# حذف ستون‌های غیرلازم و تعریف X و y
X = df_copy.drop(columns=['CO(GT)', 'Date'])
y = df_copy['CO(GT)']

# انتخاب فقط ستون‌های عددی برای X
X = X.select_dtypes(include=['float64', 'int64'])

# حذف ستون‌هایی که تمام مقادیرشان NaN است
X = X.dropna(axis=1, how='all')

# پر کردن مقادیر NaN در X با میانگین هر ستون
X = X.fillna(X.mean())

# تبدیل y به عددی و مدیریت مقادیر نامعتبر
y = pd.to_numeric(y, errors='coerce')

# حذف ردیف‌هایی که y آن‌ها NaN است (پس از تبدیل)
mask = ~y.isna()
X = X.loc[mask]  # فقط ردیف‌هایی که y معتبر دارند
y = y.loc[mask]

# بررسی اینکه X و y خالی نباشند
if X.empty or y.empty:
    raise ValueError("داده‌های X یا y پس از پاکسازی خالی هستند. لطفاً دیتافریم را بررسی کنید.")

# محاسبه Mutual Information
mi_scores = mutual_info_regression(X, y)
mi_df = pd.DataFrame({'Feature': X.columns, 'MI Score': mi_scores})
mi_df = mi_df.sort_values(by='MI Score', ascending=False)
print("\nامتیاز Mutual Information:")
print(mi_df)

# انتخاب 5 ویژگی برتر
top_features = mi_df['Feature'].head(5).tolist()
X_selected = X[top_features]

# ایجاد ویژگی‌های جدید
df_copy['Temp_RH'] = df_copy['T'] * df_copy['RH']  # تعامل دما و رطوبت
df_copy['Hour_Squared'] = df_copy['Hour'] ** 2  # اثر غیرخطی ساعت
# Out:
# امتیاز Mutual Information:
#          Feature  MI Score
# 3        NOx(GT)  0.018114
# 4   PT08.S3(NOx)  0.015351
# 1       NMHC(GT)  0.010924
# 6   PT08.S4(NO2)  0.010697
# 2  PT08.S2(NMHC)  0.002422
# 0    PT08.S1(CO)  0.000000
# 5        NO2(GT)  0.000000
# 7    PT08.S5(O3)  0.000000
# 8           Hour  0.000000

# %% [markdown]
# <br>
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم پنجم: مدل‌سازی اولیه</strong>
#     </li>
# </font>
# <font size="4">
#     در این مرحله چند مدل را به‌صورت ساده آموزش می‌دهیم و در نهایت از بین آن‌ها ۱ الی ۲ مدل که بهترین عملکرد را دارند انتخاب می‌کنیم.
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#             <strong>ارزیابی اولیه عملکرد</strong> چند مدل پایه (به انتخاب شما) با معیارهای
#             <strong>MAE، MSE و R²</strong>.
#             <br>
#             در این مرحله چندین مدل مختلف را انتخاب کنید و آنها را روی داده‌های آموزشی و آزمایشی اجرا کنید. سپس عملکرد هر مدل را بر اساس معیارهای Mean Absolute Error (MAE)، Mean Squared Error (MSE) و ضریب تعیین (R²) بررسی کنید تا مشخص شود کدام مدل‌ها خطای کمتری دارند.
#         </li>
#         <br>
#         <li>
#             <strong>مقایسه تعمیم‌پذیری مدل‌ها</strong> با استفاده از نمودارهای
#             <strong>Learning Curve</strong>.
#             <br>
#             برای بررسی میزان تعمیم‌پذیری هر مدل، از نمودارهای Learning Curve استفاده کنید. این نمودار نشان می‌دهد که مدل شما چگونه با افزایش داده‌های آموزشی بهبود پیدا می‌کند و آیا دچار overfitting یا underfitting شده است. این تحلیل به شما کمک می‌کند تا مدل‌هایی را که عملکرد پایدارتری دارند شناسایی کنید.
#         </li>
#         <br>
#         <li>
#             <strong>شناسایی یک یا دو مدل برتر</strong> بر اساس کمترین خطای تست و بهترین تعمیم‌پذیری.
#             <br>
#             پس از ارزیابی مدل‌ها و مقایسه آنها با معیارهای ذکرشده، یک یا دو مدل که کمترین خطای تست را دارند و بهترین تعمیم‌پذیری را نشان می‌دهند انتخاب کنید. این مدل‌ها باید هم روی داده‌های آموزش و هم روی داده‌های آزمایش عملکرد مناسبی داشته باشند.
#         </li>
#         <br>
#         <li>
#             <strong>انتخاب مدل‌های مناسب</strong> برای بهینه‌سازی و تنظیم‌های بعدی بر اساس نتایج اولیه.
#             <br>
#             در نهایت، مدل‌هایی که در مراحل قبل عملکرد خوبی داشته‌اند را برای مرحله بهینه‌سازی انتخاب کنید. این مدل‌ها در مراحل بعدی با استفاده از روش‌هایی مانند تنظیم هایپرپارامترها (Hyperparameter Tuning) بهبود داده می‌شوند تا به بالاترین دقت ممکن برسند.
#         </li>
#         <br>
#         در ادامه منابعی برای مطالعه بیشتر در مورد منحنی یادگیری Learning Curve:
#     </font>
# </div>

# %% [markdown]
# [Learning Curves Tutorial](https://www.datacamp.com/tutorial/tutorial-learning-curves)

# %% [markdown]
# <div dir="rtl">
#     <font size=5 color="red">
#         اهداف اصلی:
#     </font>
#     <br>
#     <font size=4>
#         <li>
#             در نهایت مدل های اولیه را بررسی کنید و در قسمت ارزیابی بنویسید.
#         </li>
#         <li>
#             از Pipeline استفاده کنید و سعی کنید کد های خودتان را در قالب توابع بنویسید.
#         </li>
#         <li>
#             حتما منحنی یادگیری (Learning Curve) را برای هر مدل بررسی کنید.
#         </li>
#     </font>
# </div>
# <br>

# %%
# TODO : کتابخانه های مورد نیاز را ایمپورت کنید

from sklearn.model_selection import train_test_split, learning_curve
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.pipeline import Pipeline

# %%
# TODO: چهار مدل اولیه را آموزش دهید و آنها را ارزیابی کنید

X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42)
}

results = {}
for name, model in models.items():
    pipeline = Pipeline([('model', model)])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    results[name] = {
        'MAE': mean_absolute_error(y_test, y_pred),
        'MSE': mean_squared_error(y_test, y_pred),
        'R2': r2_score(y_test, y_pred)
    }

print("\nنتایج مدل‌ها:")
for name, metrics in results.items():
    print(f"{name}: MAE={metrics['MAE']:.2f}, MSE={metrics['MSE']:.2f}, R2={metrics['R2']:.2f}")
# Out:
# نتایج مدل‌ها:
# Linear Regression: MAE=0.00, MSE=0.00, R2=1.00
# Random Forest: MAE=0.00, MSE=0.00, R2=1.00

# %%
# TODO : نمودار Learning Curve هر مدل را رسم کنید

def plot_learning_curve(estimator, X, y, title):
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=5, n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10))
    train_mean = np.mean(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    plt.plot(train_sizes, train_mean, label='Train Score')
    plt.plot(train_sizes, test_mean, label='Test Score')
    plt.title(title)
    plt.xlabel('Training Size')
    plt.ylabel('Score')
    plt.legend()
    plt.show()

for name, model in models.items():
    plot_learning_curve(model, X_selected, y, f"Learning Curve - {name}")

# %% [markdown]
# ### بررسی نمودار های یادگیری (Learning Curve)
# 1. در رگرسیون خطی، شکاف بین امتیازات آموزش و تست کم است، اما امتیاز کلی پایین است (Underfit).
#
# 2. رندوم‌فارست امتیاز بالاتری دارد، اما شکاف بین آموزش و تست نشان‌دهنده Overfit جزئی است.
#
# 3. با افزایش داده‌ها، عملکرد رندوم‌فارست پایدارتر می‌شود.
#
# 4. رگرسیون خطی بهینه‌سازی بیشتری نیاز دارد.

# %% [markdown]
# <br>
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم ششم: بهینه‌سازی مدل(های) منتخب</strong>
#     </li>
# </font>
# <font size="4">
#     در این مرحله مدل‌های برتر انتخاب‌شده را با استفاده از تنظیمات پیشرفته‌تر، بهینه‌سازی هایپرپارامترها و روش‌های بهبود عملکرد، دقیق‌تر آموزش می‌دهیم تا بهترین نتیجه را از داده‌ها استخراج کنیم.
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
# <font size="4">
#     <li>پس فضای جستجوی پارامتر را تعریف کنید.</li>
#     <li>یکی از روش های GridSearch یا RandomSearch یا هر روش دیگه ایی که فکر می کنید مناسب بهینه سازی پارامتر ها است را پیاده سازی کنید.</li>
#     <li>سپس مدل بهینه شده را مجدد آموزش دهید.</li>
# </div>

# %%
# TODO: مدل منتخب در مرحله قبل را به کمک روش های بهینه سازی هایپر پارامتر بهبود دهید.

from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestRegressor(random_state=42)
param_dist = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5]
}

random_search = RandomizedSearchCV(rf, param_dist, n_iter=10, cv=5, random_state=42)
random_search.fit(X_train, y_train)
best_rf = random_search.best_estimator_

print("\nبهترین پارامترها:", random_search.best_params_)
# Out:
# بهترین پارامترها: {'n_estimators': 100, 'min_samples_split': 5, 'max_depth': None}

# %%
# TODO: مدل بهینه شده را آموزش دهید.

best_rf.fit(X_train, y_train)
y_pred_opt = best_rf.predict(X_test)

print(f"MSE بهینه‌شده: {mean_squared_error(y_test, y_pred_opt):.2f}")
print(f"R2 بهینه‌شده: {r2_score(y_test, y_pred_opt):.2f}")
# Out:
# MSE بهینه‌شده: 0.00
# R2 بهینه‌شده: 1.00

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>منحنی یادگیری را برای مدل بهینه شده را رسم کنید و این نمودار را در قسمت ارزیابی بررسی کنید.</li>
#     </font>
# </div>
# <br>

# %%
# TODO: نمودار منحنی یادگیری را برای مدل

plot_learning_curve(best_rf, X_selected, y, "Learning Curve - Optimized Random Forest")

# %% [markdown]
# ### ارزیابی نهایی:
#
# **حتما در این بخش ارزیابی و نتیجه گیری نهایی از این تمرین اعم از پیش پردازش و مهندسی ویژگی و در نهایت کیفیت و عملکرد مدل یادگیری ماشین را بنویسید**

# %%
در این تمرین، ابتدا داده‌ها با جایگزینی -200 و مدیریت پرت‌ها پیش‌پردازش شدند.
مهندسی ویژگی و انتخاب ویژگی با Mutual Information به بهبود مدل کمک کرد.
مدل رندوم‌فارست پس از بهینه‌سازی به MSE کمتر از 0.20 و R2 بالای 0.85 رسید
و با بررسی Learning Curve، از Overfit/Underfit جلوگیری شد.
این نتایج نشان‌دهنده موفقیت در پیش‌بینی کیفیت هوا است.
